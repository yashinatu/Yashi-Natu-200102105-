# %%
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score

# %%
a=pd.read_csv("task2.csv")
a
# Out:
#                ID Segment type Segment Description Answer        Count  \
# 0     292890.8970          web     Meridian, Idaho     No     0.000000
# 1     292887.9870          web     Meridian, Idaho     No     0.000000
# 2     292894.0656       gender     Meridian, Idaho     No   499.173606
# 3     292887.1180          web     Meridian, Idaho     No     0.000000
# 4     292893.6561       gender     Meridian, Idaho     No   455.925963
# ...           ...          ...                 ...    ...          ...
# 1891  292887.5496          web     Meridian, Idaho     No     0.000000
# 1892  292881.6932       mobile     Meridian, Idaho     No  1203.190399
# 1893  292900.8499       gender     Meridian, Idaho     No   806.378820
# 1894  292893.8600       gender     Meridian, Idaho     No  1149.529381
# 1895  292890.2944          web     Meridian, Idaho     No     0.000000
#
#       Percentage  It became a relationship
# 0       0.000000                         0
# ...

# %%
a.shape
# Out:
# (1896, 7)

# %%
a.describe()   #Since all the couts are = 1896, thus no nan value present in data
# Out:
#                   ID        Count   Percentage  It became a relationship
# count    1896.000000  1896.000000  1896.000000               1896.000000
# mean   292999.394750   446.881267     0.254098                  0.350738
# std       227.809806   494.110578     0.220809                  0.477327
# min    292881.000000     0.000000     0.000000                  0.000000
# 25%    292888.196925     0.000000     0.000000                  0.000000
# 50%    292893.904400   400.439633     0.257873                  0.000000
# 75%    292902.568750   845.560798     0.396787                  1.000000
# max    293785.000000  1969.000000     1.000000                  1.000000

# %%
a.info() #No Nan Value present
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1896 entries, 0 to 1895
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        1896 non-null   float64
#  1   Segment type              1896 non-null   object
#  2   Segment Description       1896 non-null   object
#  3   Answer                    1896 non-null   object
#  4   Count                     1896 non-null   float64
#  5   Percentage                1896 non-null   float64
#  6   It became a relationship  1896 non-null   int64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 103.8+ KB

# %%
df=a.copy()

# %%
df=df.rename({"Segment type": "stype"}, axis=1)
df=df.rename({"It became a relationship": "Result"}, axis=1)

# %%
df
# Out:
#                ID   stype Segment Description Answer        Count  Percentage  \
# 0     292890.8970     web     Meridian, Idaho     No     0.000000    0.000000
# 1     292887.9870     web     Meridian, Idaho     No     0.000000    0.000000
# 2     292894.0656  gender     Meridian, Idaho     No   499.173606    0.225255
# 3     292887.1180     web     Meridian, Idaho     No     0.000000    0.000000
# 4     292893.6561  gender     Meridian, Idaho     No   455.925963    0.211360
# ...           ...     ...                 ...    ...          ...         ...
# 1891  292887.5496     web     Meridian, Idaho     No     0.000000    0.000000
# 1892  292881.6932  mobile     Meridian, Idaho     No  1203.190399    0.312360
# 1893  292900.8499  gender     Meridian, Idaho     No   806.378820    0.488025
# 1894  292893.8600  gender     Meridian, Idaho     No  1149.529381    0.488984
# 1895  292890.2944     web     Meridian, Idaho     No     0.000000    0.000000
#
#       Result
# 0          0
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
def f(s):
    if(s=="Yes"):
        return 1
    else:
        return 0

df.Answer = df.Answer.apply(f)

# %%
def f(s):
    if(s=="web"):
        return 0
    elif(s=="gender"):
        return 1
    elif(s=="mobile"):
        return 2
    else:
        return 3

df.stype = df.stype.apply(f)

# %%
df
# Out:
#                ID  stype Segment Description  Answer        Count  Percentage  \
# 0     292890.8970      0     Meridian, Idaho       0     0.000000    0.000000
# 1     292887.9870      0     Meridian, Idaho       0     0.000000    0.000000
# 2     292894.0656      1     Meridian, Idaho       0   499.173606    0.225255
# 3     292887.1180      0     Meridian, Idaho       0     0.000000    0.000000
# 4     292893.6561      1     Meridian, Idaho       0   455.925963    0.211360
# ...           ...    ...                 ...     ...          ...         ...
# 1891  292887.5496      0     Meridian, Idaho       0     0.000000    0.000000
# 1892  292881.6932      2     Meridian, Idaho       0  1203.190399    0.312360
# 1893  292900.8499      1     Meridian, Idaho       0   806.378820    0.488025
# 1894  292893.8600      1     Meridian, Idaho       0  1149.529381    0.488984
# 1895  292890.2944      0     Meridian, Idaho       0     0.000000    0.000000
#
#       Result
# 0          0
# ...

# %%
df.drop(["ID","Segment Description"],axis=1,inplace=True)

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size = 0.30)

# %%
x=train.drop("Result",axis=1)
y=train.Result

x1=test.drop("Result",axis=1)
y1=test.Result

# %%
model = LogisticRegression()
model.fit(x,y)
# Out:
# LogisticRegression()

# %%
prediction = model.predict(x1)
print("Accuracy from Logistic Regression model=",accuracy_score(y1,prediction))
# Out:
# Accuracy from Logistic Regression model= 0.7820738137082601

# %%
newmodel = LogisticRegression(random_state=220, C=3, multi_class="ovr").fit(x,y)
pre=newmodel.predict(x1)
print(accuracy_score(y1,pre))
# Out:
# 0.7820738137082601

# %% [markdown]
# Random Forest Classifier:

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model2=RandomForestClassifier().fit(x,y)
pre2=model2.predict(x1)

print("Accuracy of Random Forest Classifier = ",accuracy_score(y1,pre2))
# Out:
# Accuracy of Random Forest Classifier =  0.9068541300527241

# %% [markdown]
# #Changing Hyperparameters

# %%
newmodel2=RandomForestClassifier(n_estimators=50, max_depth=6, random_state=115).fit(x,y)
pre3=newmodel2.predict(x1)

print("On changing hyperparameters, accuracy = ",accuracy_score(y1,pre3))
# Out:
# On changing hyperparameters, accuracy =  0.9138840070298769
